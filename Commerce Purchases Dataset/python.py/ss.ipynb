# %%
import requests
from bs4 import BeautifulSoup

# Step 1: Send a GET request to the website
url = "https://www.shopify.com/blog/best-ecommerce-sites"
response = requests.get(url)

# Step 2: Check if the request was successful
if response.status_code == 200:
    # Step 3: Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Step 4: Find and extract the data
    # Example: Extracting article titles and their links
    articles = soup.find_all('a', class_='component--card__link')
    
    for article in articles:
        title = article.get_text(strip=True)
        link = article['href']
        full_link = f"https://www.shopify.com{link}"  # Making it a full URL
        print(f"Title: {title}\nLink: {full_link}\n")
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests 

# Making a GET request 
r = requests.get('https://www.shopify.com/blog/best-ecommerce-sites') 

 
# Check status code for response received
# Success code - 200
if r.status_code == 200:
    print("Request successful: ",r)
else:
    print(f"Request failed with status code: {r.status_code}")
# print content of request 
print(r.content)
# Out:
# Request successful:  <Response [200]>
# ...

# %%
from bs4 import BeautifulSoup

# Parse the HTML content of the webpage
soup = BeautifulSoup(r.content, 'html.parser')

# Find all links on the page
links = soup.find_all('a')

# Print the href attribute of each link
for link in links:
    print(link.get('href'))
# Out:
# #main
# https://www.shopify.com
# /start
# /website/builder
# https://themes.shopify.com?locale=en
# https://apps.shopify.com/
# /domains
# /tools
# /sell
# /checkout
# /online
# /channels
# /pos
# /markets
# /plus/solutions/b2b-ecommerce
# /payments
# /market
# /facebook-instagram
# /inbox
# /email-marketing
# /segmentation
# /manage
# /analytics
# /shipping
# /orders
# /fulfillment
# /balance
# /capital
# /flow
# https://shopify.dev
# /plus
# /enterprise
# /products
# /pricing
# https://help.shopify.com/en/
# /blog/topics/guides
# https://academy.shopify.com
# /blog
# /blog/what-is-shopify
# /editions
# /blog/topics/founder-stories
# /blog/how-to-build-a-brand
# /blog/marketing-plan
# /blog/ecommerce-seo-beginners-guide
# /blog/topics/social-media-optimization
# /blog/how-to-scale-small-business
# /tools/business-name-generator
# /tools/logo-maker
# https://www.shopify.com/stock-photos
# /blog/business-plan-template
# https://www.linkpop.com/
# /tools/qr-code-generator
# ...

# %%
# Find all paragraphs on the page
paragraphs = soup.find_all('p')

# Print the text content of each paragraph
for paragraph in paragraphs:
    print(paragraph.text)
# Out:
# Start your business.
# Build your brand
# Create your website.
# Online store editor
# Customize your store.
# Store themes
# Find business apps.
# Shopify app store
# Own your site domain.
# Domains & hosting
# Explore free business tools.
# Tools to run your business
# Sell your products.
# Sell online or in person
# Check out customers.
# World-class checkout
# Sell online.
# Grow your business online
# Sell across channels.
# Reach millions of shoppers and boost sales
# Sell in person.
# Point of Sale (POS)
# Sell globally.
# International sales
# Sell wholesale & direct.
# Business-to-business (B2B)
# Accept online payments.
# Set up forms of payment
# Market your business.
# Reach & retain customers
# Market across social.
# Social media integrations
# Chat with customers.
# Shopify Inbox
# Nurture customers.
# Shopify Email
# Know your audience.
# Gain customer insights
# Manage your business.
# Track sales, orders & analytics
# Measure your performance.
# ...

# %%
# Find all image tags on the page
images = soup.find_all('img')

# Print the src attribute of each image (image URL)
for img in images:
    print(img.get('src'))
# Out:
# https://cdn.shopify.com/b/shopify-brochure2-assets/2ecdaa09da44408d3c2a2b9cba3a2c07.png?originalWidth=1005&originalHeight=1288
# https://cdn.shopify.com/b/shopify-brochure2-assets/8262a99b5702f964162106b94a23ad2d.png?originalWidth=1005&originalHeight=1288
# https://cdn.shopify.com/b/shopify-brochure2-assets/16db235a9390238e6f9b8fd2a5c29680.png?originalWidth=1005&originalHeight=1288
# https://cdn.shopify.com/s/files/1/0070/7032/files/best-ecommerce-website-builders_34936283-c28e-41b7-89a9-2d94ce67b509.jpg?v=1691009868
# https://cdn.shopify.com/s/files/1/0070/7032/files/online-store-design-4.png?v=1691010085
# https://cdn.shopify.com/s/files/1/0070/7032/files/Outdoor_voices_784a04ba-08e8-48f1-9e76-07ed423091dd.webp?v=1691010135
# https://cdn.shopify.com/s/files/1/0070/7032/files/ecommerce-website-design-3.png?v=1691010172
# https://cdn.shopify.com/s/files/1/0070/7032/files/ecommerce-website-design-4.png?v=1691010197
# ...

# %%
# Find all tables on the page
tables = soup.find_all('table')

# Assuming you want to extract data from the first table
if tables:
    # Find all rows in the first table
    rows = tables[0].find_all('tr')
    
    # Print the data from each row
    for row in rows:
        # Find all cells in the row
        cells = row.find_all(['th', 'td'])
        # Print the text content of each cell
        for cell in cells:
            print(cell.text)
else:
    print("No tables")
# Out:
# No tables

# %%
# Find all headings on the page (h1, h2, h3, ...)
headings = [soup.find_all(f'h{i}') for i in range(1, 7)]

# Print the text content of each heading
for heading_list in headings:
    for heading in heading_list:
        print(heading.text)
# Out:
# Examples and Tips for Beautiful Ecommerce Website Design
# 4 elements of great ecommerce website design
# 25 ecommerce website design examples (and why they work)
# 8 best ecommerce website design tips
# Design a website for your ecommerce business today
# Read more
# Ecommerce website design FAQ
# Shopify
# Support
# Developers
# Products
# Global impact
# Solutions
# 1. Building trust with customers
# 2. Creating a visually compelling experience
# 3. Focusing on responsive design for mobile and desktop
# 4. Designing clear navigation
# 1. Thesus
# 2. Welly
# 3. Fred Jourdain
# 4. MVMT
# 5. Pure Cycles
# 6. Verve Coffee Roasters
# 7. Finn
# 8. Hardgraft
# 9. Topo designs
# 10. KETNIPZ
# 11. Chubbies
# 12. KITH
# 13. Personal Fav
# 14. Satya Organic
# 15. Beardbrand
# 16. Kylie Cosmetics
# 17. Allbirds
# 18. Tiny Organics
# 19. Tessemae’s
# 20. Death Wish Coffee
# 21. Almond Surfboards
# 22. Leather Head
# 23. Pura Vida Bracelets
# 24. Boba Love
# 25. Partake Foods
# ...

# %%
# Find all unordered lists on the page
unordered_lists = soup.find_all('ul')

# Print the text content of each list item in each unordered list
for ul in unordered_lists:
    list_items = ul.find_all('li')
    for li in list_items:
        print(li.text)

# Similarly, you can do the same for ordered lists (<ol>)
# Out:
# SolutionsStartStart your business.Build your brandCreate your website.Online store editorCustomize your store.Store themesFind business apps.Shopify app storeOwn your site domain.Domains & hostingExplore free business tools.Tools to run your businessSellSell your products.Sell online or in personCheck out customers.World-class checkoutSell online.Grow your business onlineSell across channels.Reach millions of shoppers and boost salesSell in person.Point of Sale (POS)Sell globally.International salesSell wholesale & direct.Business-to-business (B2B)Accept online payments.Set up forms of paymentMarketMarket your business.Reach & retain customersMarket across social.Social media integrationsChat with customers.Shopify InboxNurture customers.Shopify EmailKnow your audience.Gain customer insightsManageManage your business.Track sales, orders & analyticsMeasure your performance.Analytics and ReportingShip orders faster.Shopify ShippingManage your stock & orders.Inventory & order management
# ...

# %%
# Find all elements with class='title'
titles = soup.select('.title')

# Print the text content of each title
for title in titles:
    print(title.text)
